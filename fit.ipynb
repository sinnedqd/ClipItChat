# %% [markdown]
# # CS 486: Machine Learning - Clip It Chat! - Team Hackermans

# %% [markdown]
# ## Pre-Processing Data

# %% [markdown]
# ### Importing Packages

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Reading CSV Files

# %%
train_features = pd.read_csv("combined_csv.csv")
# df = pd.read_fwf('keywords.txt')

train_features.drop(labels = ["Unnamed: 0", "created_at"], axis = 1, inplace = True)
train_features["10_frame_MA"] = train_features.iloc[:, 1].rolling(window = 10).mean()

train_features["5_frame_MA"] = train_features.iloc[:, 1].rolling(window = 5).mean()
train_features["20_frame_MA"] = train_features.iloc[:, 1].rolling(window = 20).mean()


train_features
# Out:
#                                          body  scores  10_frame_MA  \
# 0      lived through a heart attack SeemsGood     0.0          NaN
# 1                          @junior90007 amaz3     0.0          NaN
# 2                                          D:     0.5          NaN
# 3         rooBlind rooBlind rooBlind rooBlind     0.0          NaN
# 4                                          66     0.0          NaN
# ...                                       ...     ...          ...
# 51994                                    LULW     1.0     0.428929
# 51995                                DansGame     0.7     0.498929
# 51996                                       1     0.0     0.398929
# 51997                                     LOL     1.0     0.461429
# 51998                                  monkaW     0.7     0.531429
#
#        5_frame_MA  20_frame_MA
# 0             NaN          NaN
# 1             NaN          NaN
# 2             NaN          NaN
# 3             NaN          NaN
# ...

# %%
from pandas.plotting import autocorrelation_plot

data = pd.Series(train_features["scores"])
# autocorrelation_plot(data)

data.plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
data = pd.Series(train_features["10_frame_MA"])

data.plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure(figsize = [25, 10])
plt.grid(True)
# plt.plot(train_features["scores"].iloc[: 300], label = "Scores")
plt.plot(train_features["10_frame_MA"].iloc[: 300], label = "SMA 10 Frames")

plt.plot(train_features["5_frame_MA"].iloc[: 300], label = "SMA 5 Frames")
plt.plot(train_features["20_frame_MA"].iloc[: 300], label = "SMA 20 Frames")

# %% [markdown]
# ### Tokenizing Data Values

# %%
from keras.preprocessing.text import Tokenizer

tokenizer = Tokenizer()
tokenizer.fit_on_texts(train_features)
tokenizer.texts_to_sequences(train_features)
# Out:
# [[3], [4], [5, 1, 2], [6, 1, 2], [7, 1, 2]]

# %% [markdown]
# ## Testing Linear Regression

# %%
from sklearn.linear_model import LinearRegression

lg = LinearRegression()
lg.fit(train_features, )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13316/520018828.py in <module>
#       2
#       3 lg = LinearRegression()
# ----> 4 lg.fit(train_features, )
#
# TypeError: fit() missing 1 required positional argument: 'y'
