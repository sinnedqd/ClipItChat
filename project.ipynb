# %%
import pandas as pd


search = "2018-04"
df = pd.read_pickle("data/c9sneaky.pkl")
print(df)
df.to_csv("data/loltyler1.csv")
series = df["created_at"].str.startswith(search, na=False)
filtered_df = df[series]
filtered_df.reset_index(drop=True, inplace=True)
print(filtered_df)
filtered_df.to_csv('new/loltyler1_greek_fortnite.csv')
# Out:
#                            body channel_id commenter_id commenter_type  \
# 0                         Live?   51496027    103248444           user
# 1                   YALL GOT MW   51496027    111341691           user
# 2         ADS FeelsGoodMan Clap   51496027     51196898           user
# 3        @Macaiyla FeelsGladMan   51496027    198049928           user
# 4                   Daddy live?   51496027    114290050           user
# ...                         ...        ...          ...            ...
# 4142443                       F   51496027     87123364           user
# 4142444                       f   51496027     47478098           user
# 4142445                       f   51496027     32612355           user
# 4142446                       f   51496027     54360525           user
# 4142447                       F   51496027    111033105           user
#
#                        created_at                             fragments  \
# ...
